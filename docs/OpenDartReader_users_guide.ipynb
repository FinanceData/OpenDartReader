# %% [markdown]
# # OpenDartReader - Users Guide
#
# <img width="40%" src="https://i.imgur.com/FMsL0id.png" >
#
# `OpenDartReader`는 금융감독원 전자공시 시스템의 "Open DART"서비스 API를 손쉽게 사용할 수 있도록 돕는 오픈소스 라이브러리 입니다.
#
# #### 2020-2021 [FinanceData.KR](http://financedata.kr) | [facebook.com/financedata](http://facebook.com/financedata)

# %% [markdown]
# ##  OpenDartReader
# `Open DART`는 금융감독원이 제공하는 전자공시 시스템에서 제공하는 API서비스 입니다. 기존의 "오픈API", "공시정보 활용마당" 서비스 확대개편하였으며 2020-01-21 (시범) 서비스 시작하였습니다.
#
# `Open DART` API는 매우 잘 만들어진 서비스입니다. 하지만, API를 직접사용하면 추가적인 작업들이 필요합니다. 예를 들어, `Open DART` API는 기업에 대한 내용을 조회할 때, 전자공시에서 사용하는 개별 기업의 고유 번호를 사용합니다. 특정 회사를 상장회사 종목코드으로 조회하려면 매번 고유번호를 얻어야 합니다. 수신한 데이터는 JSON혹은 XML형태 인데 대부분의 경우 pandas 데이터프레임(DataFrame)으로 가공해야 사용하기 더 편리합니다.
#
# `OpenDartReader`는 `Open DART`를 이런 내용을 일반화하고 좀 더 쉽게 `Open DART`를 사용하기 위한 파이썬 라이브러리 입니다.

# %% [markdown]
# ## Installation
#
# 다음과 같이 설치 합니다.
#
# ```bash
# pip install opendartreader
# ```
#
# 이미 설치되어 있고 업그레이드가 필요하다면 다음과 같이 설치합니다.
# ```bash
# pip install --upgrade opendartreader
# ```

# %% [markdown]
# ## Quick Start
#
#
# ### 0. 객체 생성 ###
# 객체 생성 (API KEY 지정)
#
# ```python
# import OpenDartReader
#
# api_key = 'd81e18ac719d1c1e4ec7899ef21a737ab6cbb4c7'
#
# dart = OpenDartReader(api_key)
# ```
#
# ### 1. 공시정보 ###
# ```python
# # 특정기업(삼성전자) 상장이후 모든 공시 목록 (5,600 건+)
# dart.list('삼성전자') # 기업이름 혹은,
# dart.list('005930') # 종목코드를 사용할 수 있습니다.
#
# # 특정기업(삼성전자) 특정 날짜 이후 공시목록 (날짜에 다양한 포맷이 가능합니다 2022, '2022-01-01', '20220101' )
# dart.list('삼성전자', start='2022-01-01') # 2022-01-01 ~ 오늘
# dart.list('005930', start='2022-01-01') # 2022-01-01 ~ 오늘
#
# # 특정기업(삼성전자) 특정 일자 범위(start~end)의 공시목록 (날짜에 다양한 포맷이 가능합니다)
# dart.list('005930', start='2022-04-28', end='2022-04-28')
#
# # 특정기업(삼성전자) 1999년~이후 모든 정기보고서 (정정된 공시포함)
# dart.list('005930', start='1999-01-01', kind='A', final=False)
#
# # 특정기업(삼성전자) 1999년~이후 모든 정기보고서 (최종보고서)
# dart.list('005930', start='1999-01-01', kind='A')
#
# # 2022-07-01 하루동안 모든 기업의 공시목록
# dart.list(start='20200701', end='20200701')
#
# # 2022-01-01 ~ 2022-01-10 모든 회사의 모든 공시목록 (3,139 건)
# dart.list(start='2022-01-01', end='2022-01-10')
#
# # 2022-01-01 ~ 2022-01-10 모든 회사의 모든 공시목록 (정정된 공시포함) (3,587 건)
# dart.list(start='2022-01-01', end='2022-01-10', final=False)
#
# # 2022-01-01~2022-03-30 모든 회사의 정기보고서 (corp를 특정 하지 않으면 최대 3개월) (2,352 건)
# dart.list(start='2022-01-01', end='2022-03-30', kind='A')
#
#
# # ==== 1-2. 공시정보 - 기업개황 ====
# # 기업의 개황정보
# dart.company('005930')
#
# # 회사명에 "삼성전자"가 포함된 회사들에 대한 개황정보
# dart.company_by_name('삼성전자')
#
# # ==== 1-2. 공시정보 - 기업개황 ====
# # 기업의 개황정보
# dart.company('005930')
#
# # 회사명에 "삼성전자"가 포함된 회사들에 대한 개황정보
# dart.company_by_name('삼성전자')
#
#
# # ==== 1-3. 공시정보 - 공시서류원본파일 ====
# # 삼성전자 사업보고서 (2022년 반기사업보고서) 원문 텍스트
# xml_text = dart.document('20220816001711')
#
#
# # ==== 1-4. 공시정보 - 고유번호 ====
# # 종목코드로 고유번호 얻기
# dart.find_corp_code('005930')
#
# # 기업명으로 고유번호 얻기
# dart.find_corp_code('삼성전자')
#
# ```
#
#
# ### 2. 사업보고서 ###
# 조회가능한 사업보고서의 항목: ['조건부자본증권미상환', '미등기임원보수', '회사채미상환', '단기사채미상환', '기업어음미상환', '채무증권발행', '사모자금사용', '공모자금사용', '임원전체보수승인', '임원전체보수유형', '주식총수', '회계감사', '감사용역', '회계감사용역계약', '사외이사', '신종자본증권미상환', '증자', '배당', '자기주식', '최대주주', '최대주주변동', '소액주주', '임원', '직원', '임원개인보수', '임원전체보수', '개인별보수', '타법인출자']
#
# ```python
# dart.report('005930', '미등기임원보수', 2021)  # 미등기임원 보수현황
# dart.report('005930', '증자', 2021) # 증자(감자) 현황
# dart.report('005930', '배당', 2018)  # 배당에 관한 사항
# ```
#
# ### 3. 상장기업 재무정보 ###
# 상장법인(금융업 제외)의 주요계정과목(재무상태표, 손익계산서)
#
# ```python
# # 삼성전자 2021 재무제표
# dart.finstate('삼성전자', 2021)
#
# # 삼성전자 2021Q1 재무제표
# dart.finstate('삼성전자', 2021, reprt_code='11013')
#
# # 여러 상장법인(금융업 제외)의 주요계정과목(재무상태표, 손익계산서)
# dart.finstate('00126380,00164779,00164742', 2021)
# dart.finstate('005930, 000660, 005380', 2021)
# dart.finstate('삼성전자, SK하이닉스, 현대자동차', 2021)
#
# # 재무제표 XBRL 원본 파일 저장 (삼성전자 2021 사업보고서)
# dart.finstate_xml('20220308000798', save_as='삼성전자_2021_사업보고서_XBRL.zip')
#
# # 전체 재무제표 (삼성전자 2021 전체 재무제표)
# dart.finstate_all('005930', 2021)
#
# # XBRL 표준계정과목체계(계정과목)
# dart.xbrl_taxonomy('BS1')
# ```
#
# ### 4. 지분공시 ###
# ```python
# # 대량보유 상황보고 (종목코드, 종목명, 고유번호 모두 지정 가능)
# dart.major_shareholders('삼성전자')
#
# # 임원ㆍ주요주주 소유보고 (종목코드, 종목명, 고유번호 모두 지정 가능)
# dart.major_shareholders_exec('005930')
# ```
#
# ### 5. 주요사항보고서  ###
# ```dart.event(corp, event, start=None, end=None)```
#
# 주요사항 조회가능 항목: ['부도발생', '영업정지', '회생절차', '해산사유', '유상증자', '무상증자', '유무상증자', '감자', '관리절차개시', '소송', '해외상장결정', '해외상장폐지결정', '해외상장', '해외상장폐지', '전환사채발행', '신주인수권부사채발행', '교환사채발행', '관리절차중단', '조건부자본증권발행', '자산양수도', '타법인증권양도', '유형자산양도', '유형자산양수', '타법인증권양수', '영업양도', '영업양수', '자기주식취득신탁계약해지', '자기주식취득신탁계약체결', '자기주식처분', '자기주식취득', '주식교환', '회사분할합병', '회사분할', '회사합병', '사채권양수', '사채권양도결정']
#
# ```python
# dart.event('052220', '영업정지', '2019') # iMBC(052220)
# dart.event('라이트론', '회생절차', '2019') # 라이트론(069540)
# dart.event('휴림네트웍스', '유상증자') # 휴림네트웍스(192410)
# dart.event('미원상사', '무상증자') # 미원상사(084990)
# dart.event('헬릭스미스', '유무상증자') # 헬릭스미스(084990)
# dart.event('미원상사', '감자') # 미원상사(084990)
# dart.event('한국조선해양', '소송', '2019') # 한국조선해양(009540)
# dart.event('035720', '해외상장결정', '2017') # 카카오(035720)
# dart.event('017810', '전환사채발행') # 풀무원(017810)
# dart.event('키다리스튜디오', '신주인수권부사채발행') #  키다리스튜디오(020120)
# dart.event('이스트소프트', '교환사채발행') # 이스트소프트(047560)
# ```
#
# ### 6. 증권신고서   ###
# ```dart.regstate(corp, key_word, start=None, end=None)```
#
# 조회가능한 증권신고서 항목: ['주식의포괄적교환이전', '합병', '증권예탁증권', '채무증권', '지분증권', '분할']
# 종목코드와 종목명 모두 사용할 수 있습니다. 기간(start, end)를 지정하지 않으면 기본값은 1900~현재 입니다
#
# ```python
# dart.regstate('하림지주', '주식의포괄적교환이전')
# dart.regstate('사조대림', '합병')
# dart.regstate('에스앤케이', '증권예탁증권')
# dart.regstate('BNK금융지주', '채무증권')
# dart.regstate('금호전기', '지분증권')
# dart.regstate('케이씨씨', '분할')
# ```
#
# ### 7. 확장 기능   ###
# ```python
# # 지정한 날짜의 공시목록 전체 (공시 시간 정보 포함, 종목코드 미포함)
# dart.list_date_ex('2022-10-03')
#
# # 하위 문서(sub_docs), 첨부 문서(attach_doc_list)
# rcp_no = '20220308000798'
# dart.sub_docs(rcp_no) # 하위 문서 제목과 URL
# dart.sub_docs(rcp_no, match='감사의견')  # 제목이 잘 매치되는 순서로 소트
# dart.attach_doc_list(rcp_no) # 첨부 문서(i.e. 감사보고서) 제목과 URL
# dart.attach_doc_list(rcp_no, match='감사의의견서') # 제목이 잘 매치되는 순서로 소트
#
# # 첨부 파일 제목과 URL
# dart.attach_files(rcp_no)
#
# # URL을 지정한 파일로 다운로드
# url = 'http://dart.fss.or.kr/pdf/download/excel.do?rcp_no=20220308000798&dcm_no=8446647&lang=ko'
# fn = '[삼성전자]사업보고서_재무제표(2022.03.08)_ko.xls'
# dart.download(url, fn)
# ```

# %% [markdown]
# ## 0. OpenDartReader 객체 dart를 생성
#
# 가장 먼저 해야할 일은 발급 받은 API키를 사용하여 `OpenDartReader` 객체를 생성하는 것입니다.
#
# API키는 전자공시 [인증키 신청 페이지](https://opendart.fss.or.kr/uss/umt/EgovMberInsertView.do)에서 회원가입하고 신청하면 바로 발급 받을 수 있습니다. API키는 40자의 영문과 숫자로 구성되어 있습니다.

# %%
import OpenDartReader

api_key = 'd81e78aa719d1c1e4ec7867ef22a737ab6cbb4c7'

dart = OpenDartReader(api_key)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 import OpenDartReader
#       3 api_key = 'd81e78aa719d1c1e4ec7867ef22a737ab6cbb4c7'
#       5 dart = OpenDartReader(api_key)
#
# ModuleNotFoundError: No module named 'OpenDartReader'

# %% [markdown]
# ## 1. 공시정보 검색
#
# ### list() - 공시검색  (개별종목)
# 지정한 회사의 보고서를 검색합니다. 기간과 보고서의 종류를 지정할 수 있습니다.
#
# ```python
# dart.list(corp, start=None, end=None, kind='', kind_detail='', final=True)
# ```
#
# #### 날짜 지정하는 방법
# `start`와 `end`에 지정하는 날짜의 형식 '2020-07-01', '2020-7-1', '20200701', '1 july 2020', 'JULY 1 2020' 모두 가능합니다. datetime객체도 가능합니다.
#
# * start 와 end를 함께 지정하면 start~end 기간을 지정합니다.
# * start만 지정하면 start 부터 현재까지,
# * end만 지정하면 end 하루를 지정하게 됩니다.

# %%
# 삼성전자 2019-07-01 하루 동안 공시 목록
dart.list('005930', end='2019-7-1')
# Out:
#   corp_code corp_name stock_code corp_cls            report_nm  \
# 0  00126380      삼성전자     005930        Y  임원ㆍ주요주주특정증권등소유상황보고서
#
#          rcept_no flr_nm  rcept_dt rm
# 0  20190701000283    안규리  20190701

# %%
# 삼성전자 상장이후 모든 공시 목록 (5,142 건+)
dart.list('005930', start='1900')
# Out:
#    corp_code corp_name stock_code corp_cls               report_nm  \
# 0   00126380      삼성전자     005930        Y     임원ㆍ주요주주특정증권등소유상황보고서
# 1   00126380      삼성전자     005930        Y          최대주주등소유주식변동신고서
# 2   00126380      삼성전자     005930        Y       기업설명회(IR)개최(안내공시)
# 3   00126380      삼성전자     005930        Y  연결재무제표기준영업(잠정)실적(공정공시)
# 4   00126380      삼성전자     005930        Y     임원ㆍ주요주주특정증권등소유상황보고서
# ..       ...       ...        ...      ...                     ...
# 36  00126380      삼성전자     005930        Y            채무보증(담보제공포함)
# 37  00126380      삼성전자     005930        Y           최대주주등을위한금전의대여
# 38  00126380      삼성전자     005930        Y         감사보고서 (1999.12)
# 39  00126380      삼성전자     005930        Y   [기재정정]반기보고서 (1999.06)
# 40  00126380      삼성전자     005930        Y   [기재정정]사업보고서 (1998.12)
#
#           rcept_no  flr_nm  rcept_dt rm
# 0   20210111000382     안규리  20210111
# 1   20210108800652    삼성전자  20210108  유
# 2   20210108800573    삼성전자  20210108  유
# 3   20210108800029    삼성전자  20210108  유
# 4   20210107000257  국민연금공단  20210107
# ..             ...     ...       ... ..
# 36  20000404000429    삼성전자  20000404
# 37  20000401000031    삼성전자  20000401
# 38  20000320000124  삼일회계법인  20000320
# 39  19990824000003    삼성전자  19990824
# 40  19990626000007    삼성전자  19990626  연
#
# [5241 rows x 9 columns]

# %%
# 삼성전자 2010-01-01 ~ 2019-12-31 모든 공시 목록 (2,676 건)
dart.list('005930', start='2010-01-01', end='2019-12-31')
# Out:
#    corp_code corp_name stock_code corp_cls                  report_nm  \
# 0   00126380      삼성전자     005930        Y        임원ㆍ주요주주특정증권등소유상황보고서
# 1   00126380      삼성전자     005930        Y        임원ㆍ주요주주특정증권등소유상황보고서
# 2   00126380      삼성전자     005930        Y  [기재정정]임원ㆍ주요주주특정증권등소유상황보고서
# 3   00126380      삼성전자     005930        Y        임원ㆍ주요주주특정증권등소유상황보고서
# 4   00126380      삼성전자     005930        Y        임원ㆍ주요주주특정증권등소유상황보고서
# ..       ...       ...        ...      ...                        ...
# 6   00126380      삼성전자     005930        Y        임원ㆍ주요주주특정증권등소유상황보고서
# 7   00126380      삼성전자     005930        Y  [기재정정]임원ㆍ주요주주특정증권등소유상황보고서
# 8   00126380      삼성전자     005930        Y        임원ㆍ주요주주특정증권등소유상황보고서
# 9   00126380      삼성전자     005930        Y        임원ㆍ주요주주특정증권등소유상황보고서
# 10  00126380      삼성전자     005930        Y        임원ㆍ주요주주특정증권등소유상황보고서
#
#           rcept_no flr_nm  rcept_dt rm
# 0   20191231000470    유병길  20191231
# 1   20191231000412    성인희  20191231
# 2   20191231000215    전준영  20191231
# 3   20191230000401    이상훈  20191230
# 4   20191230000200    이원진  20191230
# ..             ...    ...       ... ..
# 6   20100104000135    이상완  20100104
# 7   20100104000127    유두영  20100104
# 8   20100104000105    전준영  20100104
# 9   20100104000060    최광수  20100104
# 10  20100104000022    방상원  20100104
#
# [2511 rows x 9 columns]

# %%
# 삼성전자 1999-01-01 이후 모든 정기보고서 (85건)
dart.list('005930', start='1999-01-01', kind='A')
# Out:
#    corp_code corp_name stock_code corp_cls              report_nm  \
# 0   00126380      삼성전자     005930        Y        분기보고서 (2020.09)
# 1   00126380      삼성전자     005930        Y        반기보고서 (2020.06)
# 2   00126380      삼성전자     005930        Y        분기보고서 (2020.03)
# 3   00126380      삼성전자     005930        Y        사업보고서 (2019.12)
# 4   00126380      삼성전자     005930        Y        분기보고서 (2019.09)
# ..       ...       ...        ...      ...                    ...
# 81  00126380      삼성전자     005930        Y        반기보고서 (2000.06)
# 82  00126380      삼성전자     005930        Y  [첨부추가]사업보고서 (1999.12)
# 83  00126380      삼성전자     005930        Y        분기보고서 (2000.03)
# 84  00126380      삼성전자     005930        Y  [기재정정]반기보고서 (1999.06)
# 85  00126380      삼성전자     005930        Y  [기재정정]사업보고서 (1998.12)
#
#           rcept_no flr_nm  rcept_dt rm
# 0   20201116001248   삼성전자  20201116
# 1   20200814001766   삼성전자  20200814
# 2   20200515001451   삼성전자  20200515
# 3   20200330003851   삼성전자  20200330  연
# 4   20191114001273   삼성전자  20191114
# ..             ...    ...       ... ..
# 81  20000814000482   삼성전자  20000814
# 82  20000330000796   삼성전자  20000330  연
# 83  20000515000739   삼성전자  20000515
# 84  19990824000003   삼성전자  19990824
# 85  19990626000007   삼성전자  19990626  연
#
# [86 rows x 9 columns]

# %%
# 삼성전자 1999년~2019년 모든 정기보고서(최종보고서) (82건)
dart.list('005930', start='1999-01-01', end='2019-12-31', kind='A', final=False)
# Out:
#    corp_code corp_name stock_code corp_cls              report_nm  \
# 0   00126380      삼성전자     005930        Y        분기보고서 (2019.09)
# 1   00126380      삼성전자     005930        Y        반기보고서 (2019.06)
# 2   00126380      삼성전자     005930        Y        분기보고서 (2019.03)
# 3   00126380      삼성전자     005930        Y        사업보고서 (2018.12)
# 4   00126380      삼성전자     005930        Y        분기보고서 (2018.09)
# ..       ...       ...        ...      ...                    ...
# 82  00126380      삼성전자     005930        Y        분기보고서 (2000.03)
# 83  00126380      삼성전자     005930        Y  [기재정정]반기보고서 (1999.06)
# 84  00126380      삼성전자     005930        Y        반기보고서 (1999.06)
# 85  00126380      삼성전자     005930        Y  [기재정정]사업보고서 (1998.12)
# 86  00126380      삼성전자     005930        Y        사업보고서 (1998.12)
#
#           rcept_no flr_nm  rcept_dt  rm
# 0   20191114001273   삼성전자  20191114
# 1   20190814002218   삼성전자  20190814
# 2   20190515001605   삼성전자  20190515
# 3   20190401004781   삼성전자  20190401   연
# 4   20181114001530   삼성전자  20181114
# ..             ...    ...       ...  ..
# 82  20000515000739   삼성전자  20000515
# 83  19990824000003   삼성전자  19990824
# 84  19990814000182   삼성전자  19990814   정
# 85  19990626000007   삼성전자  19990626   연
# 86  19990403000009   삼성전자  19990403  정연
#
# [87 rows x 9 columns]

# %% [markdown]
# ### list() - 공시검색 (모든종목)
# 회사(종목)를 지정하지 않으면 모든 종목에 대한 공시를 검색합니다. (이때, 검색 기간은 `start` 와 `end` 사이의 3개월 이내 범위만 가능합니다). 주로 모든 회사를 대상으로 최근 공시를 조회할 목적으로 사용합니다

# %%
# 2020-07-01 하루동안 모든 공시목록
dart.list(end='20200701')
# Out:
#    corp_code   corp_name stock_code corp_cls  \
# 0   00260453      삼성자산운용                   E
# 1   00260453      삼성자산운용                   E
# 2   00260453      삼성자산운용                   E
# 3   00260453      삼성자산운용                   E
# 4   00260453      삼성자산운용                   E
# ..       ...         ...        ...      ...
# 20  00326272  하나유비에스자산운용                   E
# 21  00326272  하나유비에스자산운용                   E
# 22  00326272  하나유비에스자산운용                   E
# 23  00326272  하나유비에스자산운용                   E
# 24  00326272  하나유비에스자산운용                   E
#
#                                             report_nm        rcept_no  flr_nm  \
# 0    일괄신고서(집합투자증권-신탁형)(삼성연타남녀4050증권자투자신탁H[채권혼합-재간접형])  20200701000036  삼성자산운용
# 1    일괄신고서(집합투자증권-신탁형)(삼성연타남녀3040증권자투자신탁H[주식혼합-재간접형])  20200701000053  삼성자산운용
# 2    일괄신고서(집합투자증권-신탁형)(삼성연타남녀2030증권자투자신탁H[주식혼합-재간접형])  20200701000056  삼성자산운용
# 3   [기재정정]증권신고서(집합투자증권-신탁형)(삼성지수연계증권투자신탁11호[ELS-파생형])  20200701000453  삼성자산운용
# 4   [기재정정]일괄신고서(집합투자증권-신탁형)(삼성평생소득TIF40증권자투자신탁H[채권...  20200701000164  삼성자산운용
# ..                                                ...             ...     ...
# 20          효력발생안내( 2020.6.25. 제출 증권신고서(집합투자증권-신탁형) )  20200630100014   금융감독원
# 21          효력발생안내( 2020.6.25. 제출 일괄신고서(집합투자증권-신탁형) )  20200630100013   금융감독원
# 22          효력발생안내( 2020.6.25. 제출 증권신고서(집합투자증권-신탁형) )  20200630100012   금융감독원
# 23          효력발생안내( 2020.6.25. 제출 증권신고서(집합투자증권-신탁형) )  20200630100011   금융감독원
# 24          효력발생안내( 2020.6.25. 제출 증권신고서(집합투자증권-신탁형) )  20200630100010   금융감독원
#
#     rcept_dt rm
# 0   20200701
# 1   20200701
# 2   20200701
# 3   20200701
# 4   20200701
# ..       ... ..
# 20  20200701
# 21  20200701
# 22  20200701
# 23  20200701
# 24  20200701
#
# [525 rows x 9 columns]

# %%
# 2020-01-01 ~ 2020-01-10 모든 회사의 모든 공시목록
dart.list(start='2020-01-01', end='2020-01-10')
# Out:
#    corp_code    corp_name stock_code corp_cls  \
# 0   00120182       NH투자증권     005940        Y
# 1   00120182       NH투자증권     005940        Y
# 2   00120182       NH투자증권     005940        Y
# 3   00120182       NH투자증권     005940        Y
# 4   00120182       NH투자증권     005940        Y
# ..       ...          ...        ...      ...
# 5   00111722       미래에셋대우     006800        Y
# 6   00425962  삼성화재서비스손해사정                   E
# 7   01236815           선산                   E
# 8   00442233       한국산업양행                   E
# 9   00160144       한국투자증권                   E
#
#                             report_nm        rcept_no       flr_nm  rcept_dt  \
# 0   [첨부추가]일괄신고추가서류(파생결합사채-주가연계파생결합사채)  20200110000372       NH투자증권  20200110
# 1   [첨부추가]일괄신고추가서류(파생결합사채-주가연계파생결합사채)  20200110000323       NH투자증권  20200110
# 2   [첨부추가]일괄신고추가서류(파생결합사채-주가연계파생결합사채)  20200108000401       NH투자증권  20200108
# 3       [첨부추가]일괄신고추가서류(파생결합증권-주가연계증권)  20200110000678       NH투자증권  20200110
# 4       [첨부추가]일괄신고추가서류(파생결합증권-주가연계증권)  20200110000534       NH투자증권  20200110
# ..                                ...             ...          ...       ...
# 5                           증권발행실적보고서  20191231000542       미래에셋대우  20200102
# 6                 동일인등출자계열회사와의상품ㆍ용역거래  20191231000543  삼성화재서비스손해사정  20200102
# 7               [기재정정]주요사항보고서(회사합병결정)  20191231000541           선산  20200102
# 8                   연결감사보고서 (2018.12)  20191231000540       회계법인세진  20200102
# 9                           증권발행실적보고서  20191231000538       한국투자증권  20200102
#
#    rm
# 0
# 1
# 2
# 3
# 4
# .. ..
# 5
# 6   공
# 7
# 8
# 9
#
# [4110 rows x 9 columns]

# %%
# 2020-01-01 ~ 2020-01-10 모든 회사의 모든 공시목록 (정정된 공시포함)
dart.list(start='2020-01-01', end='2020-01-10', final=False)
# Out:
#    corp_code    corp_name stock_code corp_cls  \
# 0   00146427           일야     058450        K
# 1   00120182       NH투자증권     005940        Y
# 2   00120182       NH투자증권     005940        Y
# 3   00120182       NH투자증권     005940        Y
# 4   00120182       NH투자증권     005940        Y
# ..       ...          ...        ...      ...
# 71  00111722       미래에셋대우     006800        Y
# 72  00425962  삼성화재서비스손해사정                   E
# 73  01236815           선산                   E
# 74  00442233       한국산업양행                   E
# 75  00160144       한국투자증권                   E
#
#                             report_nm        rcept_no       flr_nm  rcept_dt  \
# 0       [첨부추가]주요사항보고서(타법인주식및출자증권양수결정)  20200110000851           일야  20200110
# 1   [첨부추가]일괄신고추가서류(파생결합사채-주가연계파생결합사채)  20200110000372       NH투자증권  20200110
# 2   [첨부추가]일괄신고추가서류(파생결합사채-주가연계파생결합사채)  20200110000323       NH투자증권  20200110
# 3   [첨부추가]일괄신고추가서류(파생결합사채-주가연계파생결합사채)  20200108000401       NH투자증권  20200108
# 4       [첨부추가]일괄신고추가서류(파생결합증권-주가연계증권)  20200110000678       NH투자증권  20200110
# ..                                ...             ...          ...       ...
# 71                          증권발행실적보고서  20191231000542       미래에셋대우  20200102
# 72                동일인등출자계열회사와의상품ㆍ용역거래  20191231000543  삼성화재서비스손해사정  20200102
# 73              [기재정정]주요사항보고서(회사합병결정)  20191231000541           선산  20200102
# 74                  연결감사보고서 (2018.12)  20191231000540       회계법인세진  20200102
# 75                          증권발행실적보고서  20191231000538       한국투자증권  20200102
#
#    rm
# 0   정
# 1
# 2
# 3
# 4
# .. ..
# 71
# 72  공
# 73
# 74
# 75
#
# [4876 rows x 9 columns]

# %%
# 2021-01-01 부터 현재까지 모든 회사의 정기보고서
dart.list(start='2021-01-01', kind='A')
# Out:
#    corp_code corp_name stock_code corp_cls              report_nm  \
# 0   01133466        멈스                   E        반기보고서 (2020.06)
# 1   00197759      미래산업     025560        Y  [기재정정]사업보고서 (2019.12)
# 2   01133466        멈스                   E        분기보고서 (2020.03)
# 3   00618401      크루셜텍     114120        K  [기재정정]분기보고서 (2020.09)
# 4   00808086       애니젠     196300        K  [기재정정]분기보고서 (2020.09)
# 5   01013694   인카금융서비스     211050        N  [기재정정]사업보고서 (2019.12)
# 6   01013694   인카금융서비스     211050        N  [기재정정]사업보고서 (2018.12)
# 7   01343920  유안타제4호스팩     313750        K  [기재정정]분기보고서 (2020.09)
# 8   01343920  유안타제4호스팩     313750        K  [기재정정]반기보고서 (2020.06)
# 9   01343920  유안타제4호스팩     313750        K  [기재정정]분기보고서 (2020.03)
# 10  00567222      우림기계     101170        K  [기재정정]분기보고서 (2020.09)
# 11  00814786    스카이이앤엠     131100        K  [기재정정]분기보고서 (2020.09)
# 12  01267602  유안타제3호스팩     287410        K  [기재정정]분기보고서 (2020.09)
# 13  01267602  유안타제3호스팩     287410        K  [기재정정]반기보고서 (2020.06)
# 14  01267602  유안타제3호스팩     287410        K  [기재정정]분기보고서 (2020.03)
# 15  01267602  유안타제3호스팩     287410        K  [기재정정]사업보고서 (2019.12)
# 16  01267602  유안타제3호스팩     287410        K  [기재정정]분기보고서 (2019.09)
# 17  01267602  유안타제3호스팩     287410        K  [기재정정]반기보고서 (2019.06)
# 18  01267602  유안타제3호스팩     287410        K  [기재정정]분기보고서 (2019.03)
#
#           rcept_no    flr_nm  rcept_dt rm
# 0   20210112000228        멈스  20210112
# 1   20210111000674      미래산업  20210111  연
# 2   20210111000606        멈스  20210111
# 3   20210111000504      크루셜텍  20210111
# 4   20210108000778       애니젠  20210108
# 5   20210108000667   인카금융서비스  20210108  연
# 6   20210108000631   인카금융서비스  20210108
# 7   20210108000017  유안타제4호스팩  20210108
# 8   20210108000016  유안타제4호스팩  20210108
# 9   20210108000015  유안타제4호스팩  20210108
# 10  20210107000344      우림기계  20210107
# 11  20210106000409    스카이이앤엠  20210106
# 12  20210104000376  유안타제3호스팩  20210104
# 13  20210104000364  유안타제3호스팩  20210104
# 14  20210104000357  유안타제3호스팩  20210104
# 15  20210104000351  유안타제3호스팩  20210104
# 16  20210104000343  유안타제3호스팩  20210104
# 17  20210104000326  유안타제3호스팩  20210104
# 18  20210104000297  유안타제3호스팩  20210104

# %%
# 2019-01-01 ~ 2019-03-31 모든 회사의 정기보고서
dart.list(start='20190101', end='20190331', kind='A')
# Out:
#    corp_code corp_name stock_code corp_cls              report_nm  \
# 0   00151447      천지산업     001490        E  [첨부추가]사업보고서 (2018.12)
# 1   00155498      풍림산업     001310        E  [첨부추가]사업보고서 (2018.12)
# 2   00153418      태광실업                   E  [첨부추가]사업보고서 (2018.12)
# 3   00340005   마이다스아이티                   E  [첨부추가]사업보고서 (2018.12)
# 4   00530796    미성포리테크     094700        E  [첨부추가]사업보고서 (2018.12)
# ..       ...       ...        ...      ...                    ...
# 51  00409964      하이텍팜     106190        K  [기재정정]반기보고서 (2017.06)
# 52  00409964      하이텍팜     106190        K  [기재정정]분기보고서 (2017.03)
# 53  00660033     씨엔플러스     115530        K  [기재정정]반기보고서 (2018.06)
# 54  00273615     비케이탑스     030790        Y  [첨부정정]사업보고서 (2017.12)
# 55  01264234      엘에이티     311060        N        사업보고서 (2017.12)
#
#           rcept_no   flr_nm  rcept_dt rm
# 0   20190329000292     천지산업  20190329  연
# 1   20190329003400     풍림산업  20190329  연
# 2   20190329003459     태광실업  20190329  연
# 3   20190329001776  마이다스아이티  20190329  연
# 4   20190329000118   미성포리테크  20190329  연
# ..             ...      ...       ... ..
# 51  20190108000392     하이텍팜  20190108
# 52  20190108000390     하이텍팜  20190108
# 53  20190104000332    씨엔플러스  20190104
# 54  20190102000325    비케이탑스  20190102  연
# 55  20190102000129     엘에이티  20190102
#
# [956 rows x 9 columns]

# %% [markdown]
# ### company(), company_by_name() - 기업개황
#
# ```python
# # 기업의 개황정보를 읽어옵니다
# dart.company(corp)
#
# # 기업을 검색하여 이름이 포함된 모든 기업들의 기업개황 정보를 반환합니다.
# dart.company_by_name(name)
# ```

# %%
dart.company('005930') # 삼성전자, 005930, 00126380
# Out:
# {'status': '000',
#  'message': '정상',
#  'corp_code': '00126380',
#  'corp_name': '삼성전자(주)',
#  'corp_name_eng': 'SAMSUNG ELECTRONICS CO,.LTD',
#  'stock_name': '삼성전자',
#  'stock_code': '005930',
#  'ceo_nm': '김기남, 김현석, 고동진',
#  'corp_cls': 'Y',
#  'jurir_no': '1301110006246',
#  'bizr_no': '1248100998',
#  'adres': '경기도 수원시 영통구  삼성로 129 (매탄동)',
#  'hm_url': 'www.sec.co.kr',
#  'ir_url': '',
#  'phn_no': '031-200-1114',
#  'fax_no': '031-200-7538',
#  'induty_code': '264',
#  'est_dt': '19690113',
#  'acc_mt': '12'}

# %% [markdown]
# find_company_by_name()는 기업을 검색하여 이름이 포함된 모든 기업들의 기업개황 정보를 반환합니다.
#
# 개별 회사의 corp_code(고유번호), stock_code (종목코드)를 얻는데도 유용하게 사용할 수 있습니다.

# %%
# 회사명에 삼성전자가 포함된 회사들에 대한 개황정보
data = dart.company_by_name('삼성전자')
data[:2]
# Out:
# [{'status': '000',
#   'message': '정상',
#   'corp_code': '01345812',
#   'corp_name': '삼성전자서비스씨에스 주식회사',
#   'corp_name_eng': 'SAMSUNG ELECTRONICS SERVICE CUSTOMER SATISFACTION., LTD.',
#   'stock_name': '삼성전자서비스씨에스',
#   'stock_code': '',
#   'ceo_nm': '정석진',
#   'corp_cls': 'E',
#   'jurir_no': '1358110352541',
#   'bizr_no': '7898701103',
#   'adres': '경기도 수원시 영통구 중부대로 324 (매탄동, KT동수원지사)',
#   'hm_url': '',
#   'ir_url': '',
#   'phn_no': '031-210-8938',
#   'fax_no': '031-8006-1009',
#   'induty_code': '75991',
#   'est_dt': '20181105',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '00366997',
#   'corp_name': '삼성전자로지텍(주)',
#   'corp_name_eng': 'SELC.CO.,LTD',
#   'stock_name': '삼성전자로지텍',
#   'stock_code': '',
#   'ceo_nm': '최윤범',
#   'corp_cls': 'E',
#   'jurir_no': '1301110046797',
#   'bizr_no': '1248155381',
#   'adres': '경기도 수원시 영통구 삼성로 129',
#   'hm_url': 'www.selc.co.kr',
#   'ir_url': '',
#   'phn_no': '031-270-3485',
#   'fax_no': '031-270-3673',
#   'induty_code': '52999',
#   'est_dt': '19980401',
#   'acc_mt': '12'}]

# %% [markdown]
# 가져온 기업개황 정보(dict list)를 데이터 프레임으로 가공하고, 필요한 컬럼을 지정하여 정리할 수 있습니다.

# %%
import pandas as pd

pd.DataFrame(data)[['stock_name' , 'stock_code' , 'ceo_nm' , 'corp_cls' , 'jurir_no' , 'bizr_no' , 'adres' ]]
# Out:
#    stock_name stock_code         ceo_nm corp_cls       jurir_no     bizr_no  \
# 0  삼성전자서비스씨에스                       정석진        E  1358110352541  7898701103
# 1     삼성전자로지텍                       최윤범        E  1301110046797  1248155381
# 2        삼성전자     005930  김기남, 김현석, 고동진        Y  1301110006246  1248100998
# 3     삼성전자서비스                       심원환        E  1301110049139  1248158485
# 4      삼성전자판매                       이평우        E  1801110210300  6178117517
#
#                                  adres
# 0  경기도 수원시 영통구 중부대로 324 (매탄동, KT동수원지사)
# 1                  경기도 수원시 영통구 삼성로 129
# 2           경기도 수원시 영통구  삼성로 129 (매탄동)
# 3            경기도 수원시 영통구 삼성로 290 (원천동)
# 4                 경기도 성남시 분당구 황새울로 340

# %% [markdown]
# ### document() - 공시서류 원문

# %%
# 삼성전자 사업보고서 (2018.12)
# http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20190401004781 
     
xml_text = dart.document('20190401004781') # 사업보고서 (2018.12)
xml_text[:2000]
# Out:
# '<?xml version="1.0" encoding="utf-8"?>\n\n\n<DOCUMENT xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:noNamespaceSchemaLocation="dart3.xsd">\n\n<DOCUMENT-HEADER AEXT-CLASS="Y">\n<DOCUMENT-NAME ACODE="11011">사업보고서</DOCUMENT-NAME>\n<FORMULA-VERSION ADATE="20190115">3.6</FORMULA-VERSION>\n<COMPANY-NAME AREGCIK="00126380">삼성전자</COMPANY-NAME>\n\n<SUMMARY>\n<EXTRACTION ACODE="LINK_FLAG" AFEATURE="BOTH">C</EXTRACTION>\n<EXTRACTION ACODE="FIN_TYPE" AFEATURE="BOTH">A</EXTRACTION>\n<EXTRACTION ACODE="CRP_RGS_NO_TEMP" AFEATURE="BOTH">130111-0006246</EXTRACTION>\n</SUMMARY>\n</DOCUMENT-HEADER>\n\n<BODY>\n\n<INSERTION ABASISNUMBER="SE1" AFREQUENCY="0" ADUPLICATION="N">\n<COMMENT>◆click◆ 정정문서 작성시 『정오표』 삽입</COMMENT>\n<LIBRARYLIST>정정신고(보고)-대표이사등의확인.LCommon</LIBRARYLIST>\n</INSERTION>\n\n<COVER>\n<P></P>\n<COVER-TITLE ATOC="Y" AASSOCNOTE="COVER">사 업 보 고 서</COVER-TITLE>\n<P>&cr;&cr;&cr;</P>\n<P USERMARK="F-16">                                    (제 50 기)</P>\n\n<TABLE-GROUP ACLASS="COVER" ADELETETABLE="N">\n\n<TABLE ACLASS="EXTRACTION" AFIXTABLE="Y" WIDTH="600" BORDER="0">\n\n<COLGROUP>\n<COL WIDTH="209"></COL>\n<COL WIDTH="153"></COL>\n<COL WIDTH="211"></COL>\n</COLGROUP>\n\n<TBODY>\n\n<TR ACOPY="N" ADELETE="N">\n<TD CLASS="NORMAL" ROWSPAN="2" ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="218" HEIGHT="60" AUPDATECONT="N">사업연도</TD>\n<TU CLASS="NORMAL" ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="162" HEIGHT="30" AUNIT="PERIODFROM" AUNITVALUE="20180101">2018년 01월 01일</TU>\n<TD CLASS="NORMAL" VALIGN="MIDDLE" WIDTH="220" HEIGHT="30" AUPDATECONT="N"> 부터</TD>\n</TR>\n\n<TR ACOPY="N" ADELETE="N">\n<TU CLASS="NORMAL" ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="162" HEIGHT="30" AUNIT="PERIODTO" AUNITVALUE="20181231">2018년 12월 31일</TU>\n<TD CLASS="NORMAL" VALIGN="MIDDLE" WIDTH="220" HEIGHT="30" AUPDATECONT="N"> 까지</TD>\n</TR>\n</TBODY>\n</TABLE>\n</TABLE-GROUP>\n<P></P>\n\n<TABLE AFIXTABLE="N" BORDER="0" WIDTH="600" ACLASS="NORMAL">\n\n<COLGROUP>\n<COL WIDTH="191"></COL>\n<COL WIDTH="391"></COL>\n</COLGROUP>\n\n<TBODY>\n\n<TR ACOPY="Y" ADELETE="Y">\n<TD WIDTH="200" HEIG'

# %% [markdown]
# ### find_corp_code() - 고유번호 얻기
# 종목코드 혹은 기업명으로 고유번호를 가져옵니다.
# 전자공시에서 개별 기업은 고유번호로 식별 됩니다. 특히, 상장종목이 아닌 경우는 고유번호를 사용해야 합니다.

# %%
dart.find_corp_code('005930')
# Out:
# '00126380'

# %%
dart.find_corp_code('삼성전자')
# Out:
# '00126380'

# %% [markdown]
# ### corp_codes - 고유번호(속성)
# 고유번호, 종목명, 종목코드 등의 정보를 포함하고 있는 속성값 입니다.  8만 1천여개 기업에 대한 고유번호, 종목명, 종목코드 등의 정보를 포함하고 있습니다.

# %%
dart.corp_codes
# Out:
#       corp_code          corp_name stock_code modify_date
# 0      00434003                 다코               20170630
# 1      00434456               일산약품               20170630
# 2      00430964              굿앤엘에스               20170630
# 3      00432403               한라판지               20170630
# 4      00388953  크레디피아제이십오차유동화전문회사               20170630
# ...         ...                ...        ...         ...
# 83312  01503577              비앤비레저               20200928
# 83313  01504293               파이런텍               20201007
# 83314  01504682          에이치디가양제일차               20201007
# 83315  01504691          에이치디가양제이차               20201007
# 83316  01504707          에이치디가양제삼차               20201007
#
# [83317 rows x 4 columns]

# %% [markdown]
# ## 2. 사업보고서
#
# ### report() - 사업보고서 주요정보
# 사업보고서의 주요 내용을 조회 합니다.
#
# ```python
# dart.report(corp, key_word, bsns_year, reprt_code='11011')
# ```
#
# `key_word`에 '증자','배당','자기주식','최대주주','최대주주변동','소액주주','임원','직원','임원개인보수','임원전체보수','개인별보수','타법인출자' 중의 하나를 지정할 수 있습니다.
#
# bsns_year 에 사업 년도를 지정합니다 (문자열 혹은 정수값)
#
# 함수에 대한 더 상세한 내용은 [OpenDartReader - Reference Manual]을 참고하십시오.

# %%
# 삼성전자(005930), 배당관련 사항, 2018년
dart.report('005930', '배당', 2018)
# Out:
#           rcept_no corp_cls corp_code corp_name              se      thstrm  \
# 0   20190401004781        Y  00126380      삼성전자       주당액면가액(원)         100
# 1   20190401004781        Y  00126380      삼성전자  (연결)당기순이익(백만원)  43,890,877
# 2   20190401004781        Y  00126380      삼성전자  (별도)당기순이익(백만원)  32,815,127
# 3   20190401004781        Y  00126380      삼성전자    (연결)주당순이익(원)       6,461
# 4   20190401004781        Y  00126380      삼성전자    현금배당금총액(백만원)   9,619,243
# 5   20190401004781        Y  00126380      삼성전자    주식배당금총액(백만원)           -
# 6   20190401004781        Y  00126380      삼성전자   (연결)현금배당성향(%)       21.90
# 7   20190401004781        Y  00126380      삼성전자      현금배당수익률(%)        3.70
# 8   20190401004781        Y  00126380      삼성전자      현금배당수익률(%)        4.50
# 9   20190401004781        Y  00126380      삼성전자      주식배당수익률(%)           -
# 10  20190401004781        Y  00126380      삼성전자      주식배당수익률(%)           -
# 11  20190401004781        Y  00126380      삼성전자     주당 현금배당금(원)       1,416
# 12  20190401004781        Y  00126380      삼성전자     주당 현금배당금(원)       1,417
# 13  20190401004781        Y  00126380      삼성전자      주당 주식배당(주)           -
# 14  20190401004781        Y  00126380      삼성전자      주당 주식배당(주)           -
#
#         frmtrm        lwfr stock_knd
# 0        5,000       5,000       NaN
# 1   41,344,569  22,415,655       NaN
# 2   28,800,837  11,579,749       NaN
# 3      299,868     157,967       NaN
# 4    5,826,302   3,991,892       NaN
# 5            -           -       NaN
# 6        14.10       17.80       NaN
# 7         1.70        1.60       보통주
# 8         2.10        2.00       우선주
# 9            -           -       보통주
# 10           -           -       우선주
# 11      42,500      28,500       보통주
# 12      42,550      28,550       우선주
# 13           -           -       보통주
# 14           -           -       우선주

# %%
# 서울반도체(046890), 최대주주 관한 사항, 2018년

dart.report('046890', '최대주주', 2018)
# Out:
#          rcept_no corp_cls corp_code corp_name stock_knd rm   nm relate  \
# 0  20190401003450        K  00130763     서울반도체       보통주  -  이정훈     본인
# 1  20190401003450        K  00130763     서울반도체       보통주  -  이민호  특수관계인
# 2  20190401003450        K  00130763     서울반도체       보통주  -  이민규  특수관계인
# 3  20190401003450        K  00130763     서울반도체       보통주  -    계    NaN
# 4  20190401003450        K  00130763     서울반도체         -  -    계    NaN
#
#   bsis_posesn_stock_co bsis_posesn_stock_qota_rt trmend_posesn_stock_co  \
# 0            9,749,744                     16.72              9,749,744
# 1            5,076,358                      8.71              5,076,358
# 2            5,076,358                      8.71              5,076,358
# 3           19,902,460                     34.13             19,902,460
# 4                    -                         -                      -
#
#   trmend_posesn_stock_qota_rt
# 0                       16.72
# 1                        8.71
# 2                        8.71
# 3                       34.13
# 4                           -

# %%
# 서울반도체(046890), 임원 관한 사항, 2018년

dart.report('046890', '임원', 2018)
# Out:
#          rcept_no corp_cls corp_code corp_name   nm sexdstn   birth_ym  \
# 0  20190401003450        K  00130763     서울반도체  이정훈       남  1953년 01월
# 1  20190401003450        K  00130763     서울반도체  박형건       남  1960년 04월
# 2  20190401003450        K  00130763     서울반도체  장정식       남  1955년 07월
# 3  20190401003450        K  00130763     서울반도체  오명민       남  1977년 01월
#
#        ofcps rgist_exctv_at fte_at      chrg_job  \
# 0  대표이사\n 사장           등기임원     상근          경영총괄
# 1       사외이사           등기임원    비상근  사외이사/\n 감사위원
# 2       사외이사           등기임원    비상근  사외이사/\n 감사위원
# 3       사외이사           등기임원    비상근  사외이사/\n 감사위원
#
#                                          main_career mxmm_shrholdr_relate  \
# 0                  - 삼신전기(주) 부사장\n- 서울반도체(주) 대표이사(現)                   본인
# 1  - 연세대경영학학사/서울대경영학석사수료\n- 국세청 정보공개심의위원회 위원\n- 우...                    -
# 2  - 서울대 공업화학과 학사/석사\n- Case Western Reserve 대학 공...                    -
# 3  - 서울대 원예학과 학사/석사\n- Kansas 주립대학 원예학과 박사\n- 충북대...                    -
#
#   hffc_pd  tenure_end_on
# 0  1992년~  2019년 03월 28일
# 1  2016년~  2020년 03월 27일
# 2  2018년~  2020년 03월 27일
# 3  2018년~  2020년 03월 27일

# %%
# 서울반도체(046890), 직원 관한 사항, 2018년

dart.report('046890', '직원', 2018)
# Out:
#          rcept_no corp_cls corp_code corp_name rm sexdstn fo_bbm  \
# 0  20190401003450        K  00130763     서울반도체  -       남  관리사무직
# 1  20190401003450        K  00130763     서울반도체  -       여  관리사무직
# 2  20190401003450        K  00130763     서울반도체  -       남    생산직
# 3  20190401003450        K  00130763     서울반도체  -       여    생산직
#
#   reform_bfe_emp_co_rgllbr reform_bfe_emp_co_cnttk reform_bfe_emp_co_etc  \
# 0                        -                       -                     -
# 1                        -                       -                     -
# 2                        -                       -                     -
# 3                        -                       -                     -
#
#   rgllbr_co rgllbr_abacpt_labrr_co cnttk_co cnttk_abacpt_labrr_co   sm  \
# 0       471                      -       35                     -  506
# 1       124                      -       11                     -  135
# 2       247                      -       34                     -  281
# 3       118                      -       12                     -  130
#
#   avrg_cnwk_sdytrn fyer_salary_totamt jan_salary_am
# 0              6.3     42,571,000,000    84,000,000
# 1              5.6      6,952,000,000    52,000,000
# 2              3.6     13,254,000,000    47,000,000
# 3              6.3      6,092,000,000    47,000,000

# %% [markdown]
# ## 3. 상장기업 재무정보

# %%
# 삼성전자 2018 재무제표

dart.finstate('삼성전자', 2018) # 사업보고서
# Out:
#           rcept_no reprt_code bsns_year corp_code stock_code fs_div   fs_nm  \
# 0   20190401004781      11011      2018  00126380     005930    CFS  연결재무제표
# 1   20190401004781      11011      2018  00126380     005930    CFS  연결재무제표
# 2   20190401004781      11011      2018  00126380     005930    CFS  연결재무제표
# 3   20190401004781      11011      2018  00126380     005930    CFS  연결재무제표
# 4   20190401004781      11011      2018  00126380     005930    CFS  연결재무제표
# 5   20190401004781      11011      2018  00126380     005930    CFS  연결재무제표
# 6   20190401004781      11011      2018  00126380     005930    CFS  연결재무제표
# 7   20190401004781      11011      2018  00126380     005930    CFS  연결재무제표
# 8   20190401004781      11011      2018  00126380     005930    CFS  연결재무제표
# 9   20190401004781      11011      2018  00126380     005930    CFS  연결재무제표
# 10  20190401004781      11011      2018  00126380     005930    CFS  연결재무제표
# 11  20190401004781      11011      2018  00126380     005930    CFS  연결재무제표
# 12  20190401004781      11011      2018  00126380     005930    CFS  연결재무제표
# 13  20190401004781      11011      2018  00126380     005930    OFS    재무제표
# 14  20190401004781      11011      2018  00126380     005930    OFS    재무제표
# 15  20190401004781      11011      2018  00126380     005930    OFS    재무제표
# 16  20190401004781      11011      2018  00126380     005930    OFS    재무제표
# 17  20190401004781      11011      2018  00126380     005930    OFS    재무제표
# 18  20190401004781      11011      2018  00126380     005930    OFS    재무제표
# 19  20190401004781      11011      2018  00126380     005930    OFS    재무제표
# 20  20190401004781      11011      2018  00126380     005930    OFS    재무제표
# 21  20190401004781      11011      2018  00126380     005930    OFS    재무제표
# 22  20190401004781      11011      2018  00126380     005930    OFS    재무제표
# 23  20190401004781      11011      2018  00126380     005930    OFS    재무제표
# 24  20190401004781      11011      2018  00126380     005930    OFS    재무제표
# 25  20190401004781      11011      2018  00126380     005930    OFS    재무제표
#
#    sj_div  sj_nm  account_nm thstrm_nm                thstrm_dt  \
# 0      BS  재무상태표        유동자산    제 50 기            2018.12.31 현재
# 1      BS  재무상태표       비유동자산    제 50 기            2018.12.31 현재
# 2      BS  재무상태표        자산총계    제 50 기            2018.12.31 현재
# 3      BS  재무상태표        유동부채    제 50 기            2018.12.31 현재
# 4      BS  재무상태표       비유동부채    제 50 기            2018.12.31 현재
# 5      BS  재무상태표        부채총계    제 50 기            2018.12.31 현재
# 6      BS  재무상태표         자본금    제 50 기            2018.12.31 현재
# 7      BS  재무상태표       이익잉여금    제 50 기            2018.12.31 현재
# 8      BS  재무상태표        자본총계    제 50 기            2018.12.31 현재
# 9      IS  손익계산서         매출액    제 50 기  2018.01.01 ~ 2018.12.31
# 10     IS  손익계산서        영업이익    제 50 기  2018.01.01 ~ 2018.12.31
# 11     IS  손익계산서  법인세차감전 순이익    제 50 기  2018.01.01 ~ 2018.12.31
# 12     IS  손익계산서       당기순이익    제 50 기  2018.01.01 ~ 2018.12.31
# 13     BS  재무상태표        유동자산    제 50 기            2018.12.31 현재
# 14     BS  재무상태표       비유동자산    제 50 기            2018.12.31 현재
# 15     BS  재무상태표        자산총계    제 50 기            2018.12.31 현재
# 16     BS  재무상태표        유동부채    제 50 기            2018.12.31 현재
# 17     BS  재무상태표       비유동부채    제 50 기            2018.12.31 현재
# 18     BS  재무상태표        부채총계    제 50 기            2018.12.31 현재
# 19     BS  재무상태표         자본금    제 50 기            2018.12.31 현재
# 20     BS  재무상태표       이익잉여금    제 50 기            2018.12.31 현재
# 21     BS  재무상태표        자본총계    제 50 기            2018.12.31 현재
# 22     IS  손익계산서         매출액    제 50 기  2018.01.01 ~ 2018.12.31
# 23     IS  손익계산서        영업이익    제 50 기  2018.01.01 ~ 2018.12.31
# 24     IS  손익계산서  법인세차감전 순이익    제 50 기  2018.01.01 ~ 2018.12.31
# 25     IS  손익계산서       당기순이익    제 50 기  2018.01.01 ~ 2018.12.31
#
#           thstrm_amount frmtrm_nm                frmtrm_dt  \
# 0   174,697,424,000,000    제 49 기            2017.12.31 현재
# 1   164,659,820,000,000    제 49 기            2017.12.31 현재
# 2   339,357,244,000,000    제 49 기            2017.12.31 현재
# 3    69,081,510,000,000    제 49 기            2017.12.31 현재
# 4    22,522,557,000,000    제 49 기            2017.12.31 현재
# 5    91,604,067,000,000    제 49 기            2017.12.31 현재
# 6       897,514,000,000    제 49 기            2017.12.31 현재
# 7   242,698,956,000,000    제 49 기            2017.12.31 현재
# 8   247,753,177,000,000    제 49 기            2017.12.31 현재
# 9   243,771,415,000,000    제 49 기  2017.01.01 ~ 2017.12.31
# 10   58,886,669,000,000    제 49 기  2017.01.01 ~ 2017.12.31
# 11   61,159,958,000,000    제 49 기  2017.01.01 ~ 2017.12.31
# 12   44,344,857,000,000    제 49 기  2017.01.01 ~ 2017.12.31
# 13   80,039,455,000,000    제 49 기            2017.12.31 현재
# 14  138,981,902,000,000    제 49 기            2017.12.31 현재
# 15  219,021,357,000,000    제 49 기            2017.12.31 현재
# 16   43,145,053,000,000    제 49 기            2017.12.31 현재
# 17    2,888,179,000,000    제 49 기            2017.12.31 현재
# 18   46,033,232,000,000    제 49 기            2017.12.31 현재
# 19      897,514,000,000    제 49 기            2017.12.31 현재
# 20  166,555,532,000,000    제 49 기            2017.12.31 현재
# 21  172,988,125,000,000    제 49 기            2017.12.31 현재
# 22  170,381,870,000,000    제 49 기  2017.01.01 ~ 2017.12.31
# 23   43,699,451,000,000    제 49 기  2017.01.01 ~ 2017.12.31
# 24   44,398,855,000,000    제 49 기  2017.01.01 ~ 2017.12.31
# 25   32,815,127,000,000    제 49 기  2017.01.01 ~ 2017.12.31
#
#           frmtrm_amount bfefrmtrm_nm             bfefrmtrm_dt  \
# 0   146,982,464,000,000       제 48 기            2016.12.31 현재
# 1   154,769,626,000,000       제 48 기            2016.12.31 현재
# 2   301,752,090,000,000       제 48 기            2016.12.31 현재
# 3    67,175,114,000,000       제 48 기            2016.12.31 현재
# 4    20,085,548,000,000       제 48 기            2016.12.31 현재
# 5    87,260,662,000,000       제 48 기            2016.12.31 현재
# 6       897,514,000,000       제 48 기            2016.12.31 현재
# 7   215,811,200,000,000       제 48 기            2016.12.31 현재
# 8   214,491,428,000,000       제 48 기            2016.12.31 현재
# 9   239,575,376,000,000       제 48 기  2016.01.01 ~ 2016.12.31
# 10   53,645,038,000,000       제 48 기  2016.01.01 ~ 2016.12.31
# 11   56,195,967,000,000       제 48 기  2016.01.01 ~ 2016.12.31
# 12   42,186,747,000,000       제 48 기  2016.01.01 ~ 2016.12.31
# 13   70,155,189,000,000       제 48 기            2016.12.31 현재
# 14  128,086,171,000,000       제 48 기            2016.12.31 현재
# 15  198,241,360,000,000       제 48 기            2016.12.31 현재
# 16   44,495,084,000,000       제 48 기            2016.12.31 현재
# 17    2,176,501,000,000       제 48 기            2016.12.31 현재
# 18   46,671,585,000,000       제 48 기            2016.12.31 현재
# 19      897,514,000,000       제 48 기            2016.12.31 현재
# 20  150,928,724,000,000       제 48 기            2016.12.31 현재
# 21  151,569,775,000,000       제 48 기            2016.12.31 현재
# 22  161,915,007,000,000       제 48 기  2016.01.01 ~ 2016.12.31
# 23   34,857,091,000,000       제 48 기  2016.01.01 ~ 2016.12.31
# 24   36,533,552,000,000       제 48 기  2016.01.01 ~ 2016.12.31
# 25   28,800,837,000,000       제 48 기  2016.01.01 ~ 2016.12.31
#
#        bfefrmtrm_amount ord
# 0   141,429,704,000,000   1
# 1   120,744,620,000,000   3
# 2   262,174,324,000,000   5
# 3    54,704,095,000,000   7
# 4    14,507,196,000,000   9
# 5    69,211,291,000,000  11
# 6       897,514,000,000  13
# 7   193,086,317,000,000  17
# 8   192,963,033,000,000  21
# 9   201,866,745,000,000  23
# 10   29,240,672,000,000  25
# 11   30,713,652,000,000  27
# 12   22,726,092,000,000  29
# 13   69,981,128,000,000   2
# 14  104,821,831,000,000   4
# 15  174,802,959,000,000   6
# 16   34,076,122,000,000   8
# 17    3,180,075,000,000  10
# 18   37,256,197,000,000  12
# 19      897,514,000,000  15
# 20  140,747,574,000,000  19
# 21  137,546,762,000,000  22
# 22  133,947,204,000,000  24
# 23   13,647,436,000,000  26
# 24   14,725,074,000,000  28
# 25   11,579,749,000,000  30

# %%
# 삼성전자 2018Q1 재무제표

dart.finstate('삼성전자', 2018, reprt_code='11013') # 2018년 1분기 보고서 재무제표
# Out:
#           rcept_no reprt_code bsns_year corp_code stock_code fs_div   fs_nm  \
# 0   20180515001699      11013      2018  00126380     005930    CFS  연결재무제표
# 1   20180515001699      11013      2018  00126380     005930    CFS  연결재무제표
# 2   20180515001699      11013      2018  00126380     005930    CFS  연결재무제표
# 3   20180515001699      11013      2018  00126380     005930    CFS  연결재무제표
# 4   20180515001699      11013      2018  00126380     005930    CFS  연결재무제표
# 5   20180515001699      11013      2018  00126380     005930    CFS  연결재무제표
# 6   20180515001699      11013      2018  00126380     005930    CFS  연결재무제표
# 7   20180515001699      11013      2018  00126380     005930    CFS  연결재무제표
# 8   20180515001699      11013      2018  00126380     005930    CFS  연결재무제표
# 9   20180515001699      11013      2018  00126380     005930    CFS  연결재무제표
# 10  20180515001699      11013      2018  00126380     005930    CFS  연결재무제표
# 11  20180515001699      11013      2018  00126380     005930    CFS  연결재무제표
# 12  20180515001699      11013      2018  00126380     005930    CFS  연결재무제표
# 13  20180515001699      11013      2018  00126380     005930    OFS    재무제표
# 14  20180515001699      11013      2018  00126380     005930    OFS    재무제표
# 15  20180515001699      11013      2018  00126380     005930    OFS    재무제표
# 16  20180515001699      11013      2018  00126380     005930    OFS    재무제표
# 17  20180515001699      11013      2018  00126380     005930    OFS    재무제표
# 18  20180515001699      11013      2018  00126380     005930    OFS    재무제표
# 19  20180515001699      11013      2018  00126380     005930    OFS    재무제표
# 20  20180515001699      11013      2018  00126380     005930    OFS    재무제표
# 21  20180515001699      11013      2018  00126380     005930    OFS    재무제표
# 22  20180515001699      11013      2018  00126380     005930    OFS    재무제표
# 23  20180515001699      11013      2018  00126380     005930    OFS    재무제표
# 24  20180515001699      11013      2018  00126380     005930    OFS    재무제표
# 25  20180515001699      11013      2018  00126380     005930    OFS    재무제표
#
#    sj_div  sj_nm  account_nm   thstrm_nm                thstrm_dt  \
# 0      BS  재무상태표        유동자산  제 50 기1분기말            2018.03.31 현재
# 1      BS  재무상태표       비유동자산  제 50 기1분기말            2018.03.31 현재
# 2      BS  재무상태표        자산총계  제 50 기1분기말            2018.03.31 현재
# 3      BS  재무상태표        유동부채  제 50 기1분기말            2018.03.31 현재
# 4      BS  재무상태표       비유동부채  제 50 기1분기말            2018.03.31 현재
# 5      BS  재무상태표        부채총계  제 50 기1분기말            2018.03.31 현재
# 6      BS  재무상태표         자본금  제 50 기1분기말            2018.03.31 현재
# 7      BS  재무상태표       이익잉여금  제 50 기1분기말            2018.03.31 현재
# 8      BS  재무상태표        자본총계  제 50 기1분기말            2018.03.31 현재
# 9      IS  손익계산서         매출액   제 50 기1분기  2018.01.01 ~ 2018.03.31
# 10     IS  손익계산서        영업이익   제 50 기1분기  2018.01.01 ~ 2018.03.31
# 11     IS  손익계산서  법인세차감전 순이익   제 50 기1분기  2018.01.01 ~ 2018.03.31
# 12     IS  손익계산서       당기순이익   제 50 기1분기  2018.01.01 ~ 2018.03.31
# 13     BS  재무상태표        유동자산  제 50 기1분기말            2018.03.31 현재
# 14     BS  재무상태표       비유동자산  제 50 기1분기말            2018.03.31 현재
# 15     BS  재무상태표        자산총계  제 50 기1분기말            2018.03.31 현재
# 16     BS  재무상태표        유동부채  제 50 기1분기말            2018.03.31 현재
# 17     BS  재무상태표       비유동부채  제 50 기1분기말            2018.03.31 현재
# 18     BS  재무상태표        부채총계  제 50 기1분기말            2018.03.31 현재
# 19     BS  재무상태표         자본금  제 50 기1분기말            2018.03.31 현재
# 20     BS  재무상태표       이익잉여금  제 50 기1분기말            2018.03.31 현재
# 21     BS  재무상태표        자본총계  제 50 기1분기말            2018.03.31 현재
# 22     IS  손익계산서         매출액   제 50 기1분기  2018.01.01 ~ 2018.03.31
# 23     IS  손익계산서        영업이익   제 50 기1분기  2018.01.01 ~ 2018.03.31
# 24     IS  손익계산서  법인세차감전 순이익   제 50 기1분기  2018.01.01 ~ 2018.03.31
# 25     IS  손익계산서       당기순이익   제 50 기1분기  2018.01.01 ~ 2018.03.31
#
#           thstrm_amount  frmtrm_nm                frmtrm_dt  \
# 0   154,941,953,000,000    제 49 기말            2017.12.31 현재
# 1   157,531,160,000,000    제 49 기말            2017.12.31 현재
# 2   312,473,113,000,000    제 49 기말            2017.12.31 현재
# 3    68,298,586,000,000    제 49 기말            2017.12.31 현재
# 4    20,914,647,000,000    제 49 기말            2017.12.31 현재
# 5    89,213,233,000,000    제 49 기말            2017.12.31 현재
# 6       897,514,000,000    제 49 기말            2017.12.31 현재
# 7   222,485,398,000,000    제 49 기말            2017.12.31 현재
# 8   223,259,880,000,000    제 49 기말            2017.12.31 현재
# 9    60,563,714,000,000  제 49 기1분기  2017.01.01 ~ 2017.03.31
# 10   15,642,170,000,000  제 49 기1분기  2017.01.01 ~ 2017.03.31
# 11   16,175,907,000,000  제 49 기1분기  2017.01.01 ~ 2017.03.31
# 12   11,688,544,000,000  제 49 기1분기  2017.01.01 ~ 2017.03.31
# 13   72,370,085,000,000    제 49 기말            2017.12.31 현재
# 14  132,836,079,000,000    제 49 기말            2017.12.31 현재
# 15  205,206,164,000,000    제 49 기말            2017.12.31 현재
# 16   47,168,741,000,000    제 49 기말            2017.12.31 현재
# 17    1,842,051,000,000    제 49 기말            2017.12.31 현재
# 18   49,010,792,000,000    제 49 기말            2017.12.31 현재
# 19      897,514,000,000    제 49 기말            2017.12.31 현재
# 20  154,284,538,000,000    제 49 기말            2017.12.31 현재
# 21  156,195,372,000,000    제 49 기말            2017.12.31 현재
# 22   42,606,978,000,000  제 49 기1분기  2017.01.01 ~ 2017.03.31
# 23   11,200,897,000,000  제 49 기1분기  2017.01.01 ~ 2017.03.31
# 24   11,568,977,000,000  제 49 기1분기  2017.01.01 ~ 2017.03.31
# 25    8,452,458,000,000  제 49 기1분기  2017.01.01 ~ 2017.03.31
#
#           frmtrm_amount ord   thstrm_add_amount   frmtrm_add_amount
# 0   146,982,464,000,000   1                 NaN                 NaN
# 1   154,769,626,000,000   3                 NaN                 NaN
# 2   301,752,090,000,000   5                 NaN                 NaN
# 3    67,175,114,000,000   7                 NaN                 NaN
# 4    20,085,548,000,000   9                 NaN                 NaN
# 5    87,260,662,000,000  11                 NaN                 NaN
# 6       897,514,000,000  13                 NaN                 NaN
# 7   215,811,200,000,000  17                 NaN                 NaN
# 8   214,491,428,000,000  21                 NaN                 NaN
# 9    50,547,526,000,000  23  60,563,714,000,000  50,547,526,000,000
# 10    9,898,361,000,000  25  15,642,170,000,000   9,898,361,000,000
# 11   10,164,576,000,000  27  16,175,907,000,000  10,164,576,000,000
# 12    7,684,354,000,000  29  11,688,544,000,000   7,684,354,000,000
# 13   70,155,189,000,000   2                 NaN                 NaN
# 14  128,086,171,000,000   4                 NaN                 NaN
# 15  198,241,360,000,000   6                 NaN                 NaN
# 16   44,495,084,000,000   8                 NaN                 NaN
# 17    2,176,501,000,000  10                 NaN                 NaN
# 18   46,671,585,000,000  12                 NaN                 NaN
# 19      897,514,000,000  15                 NaN                 NaN
# 20  150,928,724,000,000  19                 NaN                 NaN
# 21  151,569,775,000,000  22                 NaN                 NaN
# 22   34,578,524,000,000  24  42,606,978,000,000  34,578,524,000,000
# 23    5,675,571,000,000  26  11,200,897,000,000   5,675,571,000,000
# 24    6,309,744,000,000  28  11,568,977,000,000   6,309,744,000,000
# 25    4,873,767,000,000  30   8,452,458,000,000   4,873,767,000,000

# %% [markdown]
# ## 4. 지분공시
# * major_shareholders() - 대량보유 상황보고
# * major_shareholders_exec() - 임원ㆍ주요주주 소유보고

# %%
dart.major_shareholders('삼성전자') # 종목코드, 종목명, 고유번호 모두 가능
# Out:
#          rcept_no    rcept_dt corp_code corp_name report_tp  \
# 0  20190207000145  2019-02-07  00126380      삼성전자        약식
# 1  20190425000475  2019-04-25  00126380      삼성전자        일반
# 2  20200207000636  2020-02-07  00126380      삼성전자        약식
# 3  20200325001033  2020-03-25  00126380      삼성전자        일반
#
#                   repror          stkqy  stkqy_irds  stkrt stkrt_irds  \
# 0  BlackRockFundAdvisors    300,391,061   2,108,161   5.03       0.04
# 1                   삼성물산  1,266,296,034  -2,384,443  21.21      -0.04
# 2                 국민연금공단    638,070,003  37,907,275  10.69       0.64
# 3                   삼성물산  1,266,621,769     325,735  21.22       0.01
#
#   ctr_stkqy ctr_stkrt                report_resn
# 0         -         -      - 단순투자목적으로 장내에서 주식 매수
# 1         -         -           특별관계자 및 보유주식수 변동
# 2         -         -  단순투자목적에서 일반투자목적으로 보유목적 변경
# 3         -         -           특별관계자 및 보유주식수 변동

# %%
dart.major_shareholders_exec('삼성전자') # 종목코드, 종목명, 고유번호 모두 가능
# Out:
#            rcept_no    rcept_dt corp_code corp_name  repror  \
# 0    20190116000364  2019-01-16  00126380      삼성전자     엄대현
# 1    20190125000514  2019-01-25  00126380      삼성전자      양걸
# 2    20190129000254  2019-01-29  00126380      삼성전자  국민연금공단
# 3    20190208000342  2019-02-08  00126380      삼성전자  국민연금공단
# 4    20190211000454  2019-02-11  00126380      삼성전자     조상호
# ..              ...         ...       ...       ...     ...
# 167  20210105000198  2021-01-05  00126380      삼성전자     엄대현
# 168  20210105000353  2021-01-05  00126380      삼성전자     전승준
# 169  20210105000430  2021-01-05  00126380      삼성전자     이상훈
# 170  20210107000257  2021-01-07  00126380      삼성전자  국민연금공단
# 171  20210111000382  2021-01-11  00126380      삼성전자     안규리
#
#     isu_exctv_rgist_at isu_exctv_ofcps isu_main_shrholdr sp_stock_lmp_cnt  \
# 0                비등기임원             부사장                 -           25,000
# 1                비등기임원             부사장                 -            1,400
# 2                    -               -           10%이상주주      608,486,033
# 3                    -               -           10%이상주주      607,706,922
# 4                비등기임원              전무                 -            1,834
# ..                 ...             ...               ...              ...
# 167              비등기임원             부사장                 -           11,000
# 168              비등기임원              전무                 -           12,000
# 169              비등기임원              사장                 -           11,000
# 170                  -               -           10%이상주주      647,187,613
# 171               등기임원            사외이사                 -            2,700
#
#     sp_stock_lmp_irds_cnt sp_stock_lmp_rate sp_stock_lmp_irds_rate
# 0                  25,000              0.00                   0.00
# 1                   1,400              0.00                   0.00
# 2             608,486,033              8.96                   8.96
# 3                -779,111              8.95                  -0.01
# 4                 -19,166                 0                      0
# ..                    ...               ...                    ...
# 167                -4,000              0.00                   0.00
# 168                -2,200              0.00                   0.00
# 169                -1,000              0.00                   0.00
# 170            -7,290,212              9.53                  -0.11
# 171                   100              0.00                   0.00
#
# [172 rows x 12 columns]

# %% [markdown]
# ## 5. 확장기능
# Open DART의 API가 제공하지 않는 유용한 확장 기능을 제공합니다.

# %%
# 지정한 날짜의 공시목록 전체 (시간 정보 포함)

dart.list_date_ex('2020-01-03')
# Out:
#               rcept_dt corp_cls corp_code corp_name        rcept_no  \
# 0  2020-01-03 18:40:00     유가증권  00155355       풀무원  20200103800678
# 1  2020-01-03 18:26:00      코스닥  00475718     이엠앤아이  20200103000641
# 2  2020-01-03 18:25:00      코스닥  00475718     이엠앤아이  20200103000648
# 3  2020-01-03 18:25:00      코스닥  00475718     이엠앤아이  20200103000645
# 4  2020-01-03 18:20:00      코넥스  00978075      옐로페이  20200103600668
# ..                 ...      ...       ...       ...             ...
# 76 2020-01-03 07:30:00     기타법인  01005710    동원관광개발  20200102000464
# 77 2020-01-03 07:30:00      코스닥  00612489   아이쓰리시스템  20200102000459
# 78 2020-01-03 07:30:00      코스닥  00592653     유비벨록스  20200102000460
# 79 2020-01-03 07:30:00      코스닥  00812362       포티스  20200102000465
# 80 2020-01-03 07:30:00      코스닥  00812362       포티스  20200102000466
#
#                 report_nm    flr_nm                 rm
# 0         장래사업ㆍ경영계획(공정공시)       풀무원     한국거래소 유가증권시장본부
# 1     [기재정정]주요사항보고서(감자결정)     이엠앤아이               정정신고
# 2   [기재정정]주요사항보고서(유상증자결정)     이엠앤아이               정정신고
# 3   [기재정정]주요사항보고서(유상증자결정)     이엠앤아이               정정신고
# 4               거래처와의거래중단      옐로페이  본 문서는 한국거래소 코넥스시장
# ..                    ...       ...                ...
# 76        감사보고서 (2019.09)  예교지성회계법인
# 77    임원ㆍ주요주주특정증권등소유상황보고서       김병혁
# 78      주식등의대량보유상황보고서(일반)       이흥복
# 79         [기재정정]주주총회소집공고       포티스               정정신고
# 80             [기재정정]참고서류       포티스               정정신고
#
# [581 rows x 8 columns]

# %% [markdown]
# 보고서의 개별 문서(sub_docs)와 첨부 문서(attach_doc_list), 첨부 파일(attach_file_list)에 대한 목록을 가져옵니다.

# %%
rcp_no = '20190401004781' # 삼성전자 2018년 사업보고서

# %%
# 개별 문서 제목과 URL
dart.sub_docs(rcp_no)[:10]
# Out:
#             title                                                url
# 0       사 업 보 고 서  http://dart.fss.or.kr/report/viewer.do?rcpNo=2...
# 1  【 대표이사 등의 확인 】  http://dart.fss.or.kr/report/viewer.do?rcpNo=2...
# 2       I. 회사의 개요  http://dart.fss.or.kr/report/viewer.do?rcpNo=2...
# 3       1. 회사의 개요  http://dart.fss.or.kr/report/viewer.do?rcpNo=2...
# 4       2. 회사의 연혁  http://dart.fss.or.kr/report/viewer.do?rcpNo=2...
# 5     3. 자본금 변동사항  http://dart.fss.or.kr/report/viewer.do?rcpNo=2...
# 6     4. 주식의 총수 등  http://dart.fss.or.kr/report/viewer.do?rcpNo=2...
# 7       5. 의결권 현황  http://dart.fss.or.kr/report/viewer.do?rcpNo=2...
# 8  6. 배당에 관한 사항 등  http://dart.fss.or.kr/report/viewer.do?rcpNo=2...
# 9      II. 사업의 내용  http://dart.fss.or.kr/report/viewer.do?rcpNo=2...

# %%
# 첨부 문서 제목과 URL
dart.attach_doc_list(rcp_no)
# Out:
#                         title  \
# 0            2019.04.01 감사보고서
# 1         2019.04.01 감사의감사보고서
# 2  2019.04.01 내부감시장치에대한감사의의견서
# 3    2019.04.01 내부회계관리제도운영보고서
# 4          2019.04.01 연결감사보고서
# 5            2019.04.01 영업보고서
# 6               2019.04.01 정관
#
#                                                  url
# 0  http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20...
# 1  http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20...
# 2  http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20...
# 3  http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20...
# 4  http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20...
# 5  http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20...
# 6  http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20...

# %%
# 첨부 파일 제목과 URL
dart.attach_file_list(rcp_no)
# Out:
#                                   file_name  \
# 0               [삼성전자]사업보고서(2019.04.01).pdf
# 1             50기 사업보고서 대표이사 등의 확인서(국문).jpg
# 2                                 연구조직도.jpg
# 3       [삼성전자]사업보고서_재무제표(2019.04.01)_ko.xls
# 4  [삼성전자]사업보고서_IFRS(원문XBRL)(2019.04.01).zip
#
#                                                  url   type
# 0  http://dart.fss.or.kr/pdf/download/pdf.do?rcp_...    pdf
# 1  http://dart.fss.or.kr/pdf/download/file.do?rcp...   file
# 2  http://dart.fss.or.kr/pdf/download/file.do?rcp...   file
# 3  http://dart.fss.or.kr/pdf/download/excel.do?rc...  excel
# 4  http://dart.fss.or.kr/pdf/download/ifrs.do?rcp...   ifrs

# %%
# 삼성전자 2018년 사업보고서
attaches = dart.attach_file_list('20190401004781')
attaches
# Out:
#                                   file_name  \
# 0               [삼성전자]사업보고서(2019.04.01).pdf
# 1             50기 사업보고서 대표이사 등의 확인서(국문).jpg
# 2                                 연구조직도.jpg
# 3       [삼성전자]사업보고서_재무제표(2019.04.01)_ko.xls
# 4  [삼성전자]사업보고서_IFRS(원문XBRL)(2019.04.01).zip
#
#                                                  url   type
# 0  http://dart.fss.or.kr/pdf/download/pdf.do?rcp_...    pdf
# 1  http://dart.fss.or.kr/pdf/download/file.do?rcp...   file
# 2  http://dart.fss.or.kr/pdf/download/file.do?rcp...   file
# 3  http://dart.fss.or.kr/pdf/download/excel.do?rc...  excel
# 4  http://dart.fss.or.kr/pdf/download/ifrs.do?rcp...   ifrs

# %%
xls_url = attaches.loc[attaches['type']=='excel', 'url'].values[0] # 첨부 재무제표 엑셀
xls_url
# Out:
# 'http://dart.fss.or.kr/pdf/download/excel.do?rcp_no=20190401004781&dcm_no=6616741&lang=ko'

# %%
dart.retrieve(xls_url, '삼성전자_2018.xls')
# Out:
# '삼성전자_2018.xls'

# %%
import pandas as pd

xl = pd.ExcelFile('삼성전자_2018.xls')
xl.sheet_names
# Out:
# ['기본정보',
#  '연결 재무상태표',
#  '연결 손익계산서',
#  '연결 포괄손익계산서',
#  '연결 자본변동표',
#  '연결 현금흐름표',
#  '재무상태표',
#  '손익계산서',
#  '포괄손익계산서',
#  '자본변동표',
#  '현금흐름표']

# %%
pd.read_excel('삼성전자_2018.xls', sheet_name='연결 손익계산서', skiprows=6)
# Out:
#                                        제 50 기     제 49 기     제 48 기
# 0                          수익(매출액)  243771415  239575376  201866745
# 1                             매출원가  132394411  129290661  120277715
# 2                            매출총이익  111377004  110284715   81589030
# 3                          판매비와관리비   52490335   56639677   52348358
# 4                         영업이익(손실)   58886669   53645038   29240672
# 5                             기타수익    1485037    3010657    3238261
# 6                             기타비용    1142018    1419648    2463814
# 7                            지분법이익     539845     201442      19501
# 8                             금융수익    9999321    9737391   11385645
# 9                             금융비용    8608896    8978913   10706613
# 10                 법인세비용차감전순이익(손실)   61159958   56195967   30713652
# 11                           법인세비용   16815101   14009220    7987560
# 12                      계속영업이익(손실)   44344857   42186747   22726092
# 13                       당기순이익(손실)   44344857   42186747   22726092
# 14                   당기순이익(손실)의 귀속
# 15      지배기업의 소유주에게 귀속되는 당기순이익(손실)   43890877   41344569   22415655
# 16           비지배지분에 귀속되는 당기순이익(손실)     453980     842178     310437
# 17                            주당이익
# 18             기본주당이익(손실) (단위 : 원)       6461       5997       3159
# 19             희석주당이익(손실) (단위 : 원)       6461       5997       3159

# %% [markdown]
# #### 2021  [FinanceData.KR](http://financedata.kr) | [facebook.com/financedata](http://facebook.com/financedata)
